# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('train.csv')
df_t=pd.read_csv('test.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_t
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df=df.drop('Cabin',axis=1)
df=df.drop('Ticket',axis=1)
df=df.drop('Name',axis=1)
df_t=df_t.drop('Cabin',axis=1)
df_t=df_t.drop('Ticket',axis=1)
df_t=df_t.drop('Name',axis=1)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# Embarked         2
# dtype: int64

# %%
df_t.isnull().sum()
# Out:
# PassengerId     0
# Pclass          0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Fare            1
# Embarked        0
# dtype: int64

# %%
df['Age'].fillna(df['Age'].mode()[0],inplace=True)
df_t['Age'].fillna(df_t['Age'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       2
# dtype: int64

# %%
df_t.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           1
# Embarked       0
# dtype: int64

# %%
df.shape
# Out:
# (891, 9)

# %%
df=df.dropna()
df_t=df_t.dropna()

# %%
df.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass   Sex         Age       SibSp  \
# count    889.000000  889.000000  889.000000   889  889.000000  889.000000
# unique          NaN         NaN         NaN     2         NaN         NaN
# top             NaN         NaN         NaN  male         NaN         NaN
# freq            NaN         NaN         NaN   577         NaN         NaN
# mean     446.000000    0.382452    2.311586   NaN   28.518751    0.524184
# std      256.998173    0.486260    0.834700   NaN   13.162820    1.103705
# min        1.000000    0.000000    1.000000   NaN    0.420000    0.000000
# 25%      224.000000    0.000000    2.000000   NaN   22.000000    0.000000
# 50%      446.000000    0.000000    3.000000   NaN   24.000000    0.000000
# 75%      668.000000    1.000000    3.000000   NaN   35.000000    1.000000
# max      891.000000    1.000000    3.000000   NaN   80.000000    8.000000
#
#              Parch        Fare Embarked
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    int64
#  1   Survived     889 non-null    int64
#  2   Pclass       889 non-null    int64
#  3   Sex          889 non-null    object
#  4   Age          889 non-null    float64
#  5   SibSp        889 non-null    int64
#  6   Parch        889 non-null    int64
#  7   Fare         889 non-null    float64
#  8   Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 69.5+ KB

# %%
df_t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 417 entries, 0 to 417
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  417 non-null    int64
#  1   Pclass       417 non-null    int64
#  2   Sex          417 non-null    object
#  3   Age          417 non-null    float64
#  4   SibSp        417 non-null    int64
#  5   Parch        417 non-null    int64
#  6   Fare         417 non-null    float64
#  7   Embarked     417 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 29.3+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df_t.duplicated().sum()
# Out:
# 0

# %%
df['Sex']=df['Sex'].map({'male':0,'female':1})
df_t['Sex']=df_t['Sex'].map({'male':0,'female':1})

# %%
df['Embarked']=df['Embarked'].map({'S':1,'C':2,'Q':3})
df_t['Embarked']=df_t['Embarked'].map({'S':1,'C':2,'Q':3})

# %%
columns_names=['PassengerId','Pclass','Sex','Age','SibSp','Parch','Fare','Embarked']
df
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0              1         0       3    0  22.0      1      0   7.2500         1
# 1              2         1       1    1  38.0      1      0  71.2833         2
# 2              3         1       3    1  26.0      0      0   7.9250         1
# 3              4         1       1    1  35.0      1      0  53.1000         1
# 4              5         0       3    0  35.0      0      0   8.0500         1
# ..           ...       ...     ...  ...   ...    ...    ...      ...       ...
# 886          887         0       2    0  27.0      0      0  13.0000         1
# 887          888         1       1    1  19.0      0      0  30.0000         1
# 888          889         0       3    1  24.0      1      2  23.4500         1
# 889          890         1       1    0  26.0      0      0  30.0000         2
# 890          891         0       3    0  32.0      0      0   7.7500         3
#
# [889 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    int64
#  1   Survived     889 non-null    int64
#  2   Pclass       889 non-null    int64
#  3   Sex          889 non-null    int64
#  4   Age          889 non-null    float64
#  5   SibSp        889 non-null    int64
#  6   Parch        889 non-null    int64
#  7   Fare         889 non-null    float64
#  8   Embarked     889 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 69.5 KB

# %%
df_t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 417 entries, 0 to 417
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  417 non-null    int64
#  1   Pclass       417 non-null    int64
#  2   Sex          417 non-null    int64
#  3   Age          417 non-null    float64
#  4   SibSp        417 non-null    int64
#  5   Parch        417 non-null    int64
#  6   Fare         417 non-null    float64
#  7   Embarked     417 non-null    int64
# dtypes: float64(2), int64(6)
# memory usage: 29.3 KB

# %%
x=df.drop('Survived',axis=1)
y=df['Survived']
x_test=df_t[columns_names]

# %%
lr=LinearDiscriminantAnalysis()
lr.fit(x,y)
# Out:
# LinearDiscriminantAnalysis()

# %%
y_pred=lr.predict(x_test)
lr.score(x_test,y_pred)
# Out:
# 1.0

# %%
x_test['Survived']=y_pred
x_test
# Out:
#      PassengerId  Pclass  Sex   Age  SibSp  Parch      Fare  Embarked  \
# 0            892       3    0  34.5      0      0    7.8292         3
# 1            893       3    1  47.0      1      0    7.0000         1
# 2            894       2    0  62.0      0      0    9.6875         3
# 3            895       3    0  27.0      0      0    8.6625         1
# 4            896       3    1  22.0      1      1   12.2875         1
# ..           ...     ...  ...   ...    ...    ...       ...       ...
# 413         1305       3    0  21.0      0      0    8.0500         1
# 414         1306       1    1  39.0      0      0  108.9000         2
# 415         1307       3    0  38.5      0      0    7.2500         1
# 416         1308       3    0  21.0      0      0    8.0500         1
# 417         1309       3    0  21.0      1      1   22.3583         2
#
#      Survived
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# ..        ...
# 413         0
# ...

# %%
The_prediction=x_test
The_prediction['Sex']=The_prediction['Sex'].map({0:'male',1:'female'})
The_prediction['Embarked']=The_prediction['Embarked'].map({1:'S',2:'C',3:'Q'})
The_prediction
#The_prediction.to_csv('Titanic survived predicton')
# Out:
#      PassengerId  Pclass     Sex   Age  SibSp  Parch      Fare Embarked  \
# 0            892       3    male  34.5      0      0    7.8292        Q
# 1            893       3  female  47.0      1      0    7.0000        S
# 2            894       2    male  62.0      0      0    9.6875        Q
# 3            895       3    male  27.0      0      0    8.6625        S
# 4            896       3  female  22.0      1      1   12.2875        S
# ..           ...     ...     ...   ...    ...    ...       ...      ...
# 413         1305       3    male  21.0      0      0    8.0500        S
# 414         1306       1  female  39.0      0      0  108.9000        C
# 415         1307       3    male  38.5      0      0    7.2500        S
# 416         1308       3    male  21.0      0      0    8.0500        S
# 417         1309       3    male  21.0      1      1   22.3583        C
#
#      Survived
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# ...
